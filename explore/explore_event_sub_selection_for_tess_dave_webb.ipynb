# %%
# Standard modules
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Read in the data and take a quick look at it

# %%
# Read in the JEDI catalog
csv_filename = '/Users/jmason86/Dropbox/Research/Postdoc_NASA/Analysis/Coronal Dimming Analysis/JEDI Catalog/jedi_v2.csv'
jedi = pd.read_csv(csv_filename, low_memory=False)

# %%
print(jedi.shape)
jedi.head()
# Out:
# (5262, 27349)
#    Event # GOES Flare Start Time GOES Flare Peak Time GOES Flare Class  \
# 0      1.0   2010-05-04 16:15:00  2010-05-04 16:29:00             C3.6
# 1      2.0   2010-05-05 07:09:00  2010-05-05 07:16:00             C2.3
# 2      3.0   2010-05-05 11:37:00  2010-05-05 11:52:00             C8.8
# 3      4.0   2010-05-05 17:13:00  2010-05-05 17:19:00             M1.2
# 4      5.0   2010-05-07 07:29:00  2010-05-07 07:42:00             C2.0
#
#   Pre-Flare Start Time Pre-Flare End Time  Flare Interrupt  \
# 0     2010-05-05 02:16   2010-05-05 07:16             True
# 1     2010-05-05 02:16   2010-05-05 07:16             True
# 2     2010-05-05 12:19   2010-05-05 17:19             True
# 3     2010-05-07 02:42   2010-05-07 07:42            False
# 4     2010-05-07 23:59   2010-05-08 04:59             True
#
#    Flare Latitude [deg]  Flare Longitude [deg]  Flare Position Angle [deg]  \
# 0                  41.0                   23.0                  330.708637
# ...

# %% [markdown]
# ## New dataframe of just Dave and Alysha's events

# %%
jedi.iloc[1520:1535]['GOES Flare Start Time']
jedi.iloc[2020:2030]['GOES Flare Class']
# Out:
# 2020    C2.0
# 2021    C1.6
# 2022    C2.5
# 2023    C5.0
# 2024    C2.6
# 2025    M1.9
# 2026    C4.0
# 2027    C3.0
# 2028    C3.4
# 2029    C1.1
# Name: GOES Flare Class, dtype: object

# %%
event_numbers = [30, 93, 142, 576, 589, 590, 673, 682, 785, 810, 901, 954, 1478, 1487, 1535, 1535, 
                 1552, 1588, 1589, 1617, 1968, 2026, 2128, 2143, 2244, 3040, 3568, 3701]
jedi_sub = jedi[jedi['Event #'].isin(event_numbers)]
jedi_sub
# Out:
#       Event # GOES Flare Start Time GOES Flare Peak Time GOES Flare Class Pre-Flare Start Time Pre-Flare End Time  Flare Interrupt  Flare Latitude [deg]  Flare Longitude [deg]  Flare Position Angle [deg]  9.4 Pre-Flare Irradiance [W/m2]  13.1 Pre-Flare Irradiance [W/m2]  13.3 Pre-Flare Irradiance [W/m2]  17.1 Pre-Flare Irradiance [W/m2]  17.7 Pre-Flare Irradiance [W/m2]  18.0 Pre-Flare Irradiance [W/m2]  19.5 Pre-Flare Irradiance [W/m2]  20.2 Pre-Flare Irradiance [W/m2]  21.1 Pre-Flare Irradiance [W/m2]  25.6 Pre-Flare Irradiance [W/m2]  28.4 Pre-Flare Irradiance [W/m2]  30.4 Pre-Flare Irradiance [W/m2]  33.5 Pre-Flare Irradiance [W/m2]  36.1 Pre-Flare Irradiance [W/m2]  36.8 Pre-Flare Irradiance [W/m2]  44.6 Pre-Flare Irradiance [W/m2]  46.5 Pre-Flare Irradiance [W/m2]  49.9 Pre-Flare Irradiance [W/m2]  52.1 Pre-Flare Irradiance [W/m2]  52.6 Pre-Flare Irradiance [W/m2]  53.7 Pre-Flare Irradiance [W/m2]  55.4 Pre-Flare Irradiance [W/m2]  56.8 Pre-Flare Irradiance [W/m2]  \
# ...

# %% [markdown]
# # Break out parameters for Dave subsample

# %%
cols = [col for col in jedi_sub.columns if 'Depth Max' in col or 'Depth Max Time' in col or 'Event #' in col]
depth = jedi_sub[cols].dropna(how='all')

# %%
cols = [col for col in jedi_sub.columns if 'Slope Mean' in col or 'GOES Flare Peak Time' in col or 'Event #' in col]
slope = jedi_sub[cols].dropna(how='all')

# %%
cols = [col for col in jedi_sub.columns if 'Duration' in col or 'GOES Flare Peak Time' in col or 'Event #' in col]
duration = jedi_sub[cols].dropna(how='all')

# %% [markdown]
# ## All non-nan parameters, one event at a time

# %% [markdown]
# Just work way through the sub event index and make decisions by hand

# %%
sub_event_index = 26

# %%
depth.iloc[sub_event_index].dropna()
# Out:
# Event #                                      3701
# 20.2 Depth Max Time           2013-09-29 23:57:08
# 20.2 Depth Max [%]                        2.55829
# 17.1 by 20.2 Depth Max [%]    2013-09-30 02:34:08
# Name: 3700, dtype: object

# %%
slope.iloc[sub_event_index].dropna()
# Out:
# Event #                                         3701
# GOES Flare Peak Time             2013-09-29 23:39:00
# 20.2 Slope Mean [%/s]                     4.8846e-06
# 17.1 by 20.2 Slope Mean [%/s]            0.000686253
# 20.2 by 17.1 Slope Mean [%/s]            4.14548e-05
# Name: 3700, dtype: object

# %%
duration.iloc[sub_event_index].dropna()
# Out:
# Event #                                            3701
# GOES Flare Peak Time                2013-09-29 23:39:00
# 20.2 Duration Start Time            2013-09-30 15:16:08
# 20.2 Duration End Time              2013-09-30 15:20:08
# 20.2 Duration [s]                                   240
# 17.1 by 20.2 Duration Start Time                  16320
# 13.1 by 17.1 Duration End Time                    53580
# 13.1 by 20.2 Duration End Time                    54240
# 17.1 by 13.1 Duration End Time                   -53580
# 17.1 by 20.2 Duration End Time                      660
# 20.2 by 13.1 Duration End Time                   -54240
# 20.2 by 17.1 Duration End Time                     -660
# 17.1 by 20.2 Duration [s]                      -4.45672
# 20.2 by 17.1 Duration [s]                      0.235876
# Name: 3700, dtype: object
